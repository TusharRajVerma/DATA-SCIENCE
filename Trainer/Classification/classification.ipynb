# %%
import pandas as pd
import sklearn
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn import preprocessing

# %%
df=pd.read_excel(r'default_of_credit_card_clients_0.xlsx',sheet_name='Data')

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2      0
# 1          2     120000    2          2         2   26      0      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43      0      0      0
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1      0      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
X = df.iloc[:,1:24]
y= df.iloc[:,24:]
X.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2      0      0
# 1     120000    2          2         2   26      0      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57      0      0      0      0
#
#    PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0      0  ...        689          0          0          0         0       689
# 1      0  ...       2682       3272       3455       3261         0      1000
# 2      0  ...      13559      14331      14948      15549      1518      1500
# 3      0  ...      49291      28314      28959      29547      2000      2019
# 4      0  ...      35835      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y , test_size =0.25)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,pred)
# Out:
# 0.7269333333333333

# %%
pred2=model.predict(X_train)
accuracy_score(y_train,pred2)
# Out:
# 0.9994222222222222

# %%
print(metrics.confusion_matrix(y_train, pred2))
# Out:
# [[17589     0]
#  [   13  4898]]

# %%
print(metrics.confusion_matrix(y_test, pred))
# Out:
# [[4744 1031]
#  [1017  708]]

# %%
df['default payment next month'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: default payment next month, dtype: int64

# %%
#As data set is not normally distributed so there is difference between 
#train and test accuracy so will chose the normal distributed sample
df1=df.loc[df['default payment next month']==0]
df1=df1.reset_index()
df2=df.loc[df['default payment next month']==1]
df1=df1.loc[:6637,:]

# %%
result = pd.concat([df1, df2])

# %%
result=result.reset_index()
result
# Out:
#        level_0  index     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  \
# 0            0    2.0      3      90000    2          2         2   34      0
# 1            1    3.0      4      50000    2          2         1   37      0
# 2            2    4.0      5      50000    1          2         1   57      0
# 3            3    5.0      6      50000    1          1         2   37      0
# 4            4    6.0      7     500000    1          1         2   29      0
# ...        ...    ...    ...        ...  ...        ...       ...  ...    ...
# 13269    29991    NaN  29992     210000    1          2         1   34      3
# 13270    29994    NaN  29995      80000    1          2         2   34      2
# 13271    29997    NaN  29998      30000    1          2         2   37      4
# 13272    29998    NaN  29999      80000    1          3         1   41      1
# 13273    29999    NaN  30000      50000    1          2         1   46      0
#
# ...

# %%
X1 = result.iloc[:,2:26]
y1= result.iloc[:,26:]
y1
# Out:
#        default payment next month
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ...                           ...
# 13269                           1
# 13270                           1
# 13271                           1
# 13272                           1
# 13273                           1
#
# [13274 rows x 1 columns]

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
X1_train, X1_test, y1_train, y1_test = train_test_split(X1,y1 , test_size =0.25)

# %%
model.fit(X1_train,y1_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
pre=model.predict(X1_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y1_test,pre)
# Out:
# 0.8273576378427238

# %%
pre1=model.predict(X1_train)

# %%
accuracy_score(y1_train,pre1)
# Out:
# 1.0

# %%
#The test accuray gets increases
